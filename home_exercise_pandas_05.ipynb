# %%
import numpy as np
import pandas as pd

# %%
# 1
csv_df = pd.read_csv(r"hw_work.csv")
print(csv_df.info())
# There are 20 columns in the table
# There are 3333 rows in the table
# There are missing values in 9 columns for example in 'Total day charge' coulumn there are 8 missing values
# The data frame memory usage is 520.9+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
# 2
print(csv_df['Account length'].describe())
# the max value is 243
# the min value is 1
# the average value is 101.064806
# the number of rows in this column is 3333
# Out:
# count    3333.000000
# mean      101.064806
# std        39.822106
# min         1.000000
# 25%        74.000000
# 50%       101.000000
# 75%       127.000000
# max       243.000000
# Name: Account length, dtype: float64

# %%
# 3
print(csv_df.describe().transpose())
# Out:
#                          count        mean        std     min     25%     50%  \
# Account length          3333.0  101.064806  39.822106    1.00   74.00  101.00
# Area code               3333.0  437.182418  42.371290  408.00  408.00  415.00
# Number vmail messages   3333.0    8.099010  13.688365    0.00    0.00    0.00
# Total day minutes       3323.0  179.787150  54.419625    0.00  143.70  179.40
# Total day calls         3323.0  100.456214  20.057356    0.00   87.00  101.00
# Total day charge        3315.0   30.557831   9.255987    0.00   24.42   30.50
# Total eve minutes       3324.0  201.033935  50.676652    0.00  166.60  201.40
# Total eve calls         3325.0  100.110677  19.932115    0.00   87.00  100.00
# Total eve charge        3333.0   17.083540   4.310668    0.00   14.16   17.12
# Total night minutes     3333.0  200.872037  50.573847   23.20  167.00  201.20
# Total night calls       3332.0  100.115246  19.566710   33.00   87.00  100.00
# ...

# %%
# 4
print('five first rows:')
print()
print(csv_df.head(5))
print()
print('five last rows:')
print()
print(csv_df.tail(5))
# Out:
# five first rows:
#
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# 5
print(csv_df['State'])
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
# 6
print(csv_df[['State', 'International plan']])
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]

# %%
# 7
print(csv_df[csv_df['International plan'].isin(['Yes'])])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 7       MO             147        415                Yes              No
# 9       WV             141        415                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3304    IL              71        510                Yes              No
# 3309    VT             100        408                Yes              No
# 3317    SD             163        415                Yes              No
# 3320    GA             122        510                Yes              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 8
print(csv_df[(csv_df['International plan'].isin(['Yes'])) & (csv_df['Churn'].isin([True]))])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 41      MD             135        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
# 144     VT             117        408                Yes              No
# 198     ME             131        510                Yes             Yes
# 214     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3246    NC              77        408                Yes             Yes
# 3255    RI             138        510                Yes              No
# 3291    MI             119        510                Yes             Yes
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 9
print(csv_df.iloc[14])
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
# 10
print(csv_df.iloc[14:])
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 14      IA              62        415                 No              No
# 15      NY             161        415                 No              No
# 16      ID              85        408                 No             Yes
# 17      VT              93        510                 No              No
# 18      VA              76        510                 No             Yes
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 11
csv_df.set_index('State', inplace=True)
print(csv_df.loc['LA'])
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# LA                117        408                 No              No
# LA                172        408                 No              No
# LA                155        415                 No              No
# LA                121        408                 No              No
# LA                151        408                 No              No
# LA                179        408                 No              No
# LA                 99        415                 No              No
# LA                 93        415                 No              No
# LA                149        415                 No             Yes
# LA                 67        510                 No              No
# LA                172        415                 No              No
# LA                 43        415                 No              No
# LA                158        408                 No              No
# ...

# %%
# 12
csv_df_drop_column = csv_df.drop('Area code', axis=1)
print(csv_df_drop_column)
# Out:
#        Account length International plan Voice mail plan  \
# State
# KS                128                 No             Yes
# OH                107                 No             Yes
# NJ                137                 No              No
# OH                 84                Yes              No
# OK                 75                Yes              No
# ...               ...                ...             ...
# AZ                192                 No             Yes
# WV                 68                 No              No
# RI                 28                 No              No
# CT                184                Yes              No
# TN                 74                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# ...

# %%
# 13
csv_df.reset_index(inplace=True) 
csv_df_drop_row = csv_df.drop(3328, axis=0)
print(csv_df_drop_row)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 14
csv_df['total_min'] = csv_df['Total night minutes'].add(csv_df['Total intl minutes'], fill_value=0)
csv_df['average_min'] = (csv_df['Total night minutes'] + csv_df['Total intl minutes']) / 2
print(csv_df)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 15
csv_concat_df = pd.concat([csv_df.head(1), csv_df.tail(1)], ignore_index=True)
print(csv_concat_df)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    TN              74        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     25              234.4            113.0
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# 1             39.85              265.9  ...                241.4
#
#    Total night calls  Total night charge  Total intl minutes  \
# 0               91.0               11.01                10.0
# 1               77.0               10.86                13.7
#
#    Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                 3                2.7                     1.0  False
# ...

# %%
# 16
row = {'State': 'KS', 'Account length': 128, 'Area code': 415, 'International plan': 'No', 'Voice mail plan': 'Yes', 'Number vmail messages': 20, 
       'Total day minutes': 280.4, 'Total day calls': 105.0, 'Total day charge': 40.65, 'Total eve minutes': 190.5, 'Total eve calls': 95.4,
       'Total eve charge': 16.05, 'Total night minutes' :220.6, 'Total night calls' :60.5, 'Total night charge' :10.5,
       'Total intl minutes': 12.3, 'Total intl calls': 5, 'Total intl charge': 3.7, 'Customer service calls': 1.0,
       'Churn' :True}

pd_new = pd.DataFrame([row])
csv_cont_df = pd.concat([csv_df, pd.DataFrame([row])], ignore_index=True)
print(csv_cont_df)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
# 3333    KS             128        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
# 17
# inplace parameter in a certain function allows to choose whether to perform the operation on the existing dataframe or save the results on new dataframe.

# %%
# 18
# When a column in a table is turned into an index, it can no longer be used as a column because it disappears from the table and becomes used as an index

# %%
# 19
# axis = 0 - Used as a parameter in a function to indicate that the operation will be performed on the row
# axis = 1 - Used as a parameter in a function to indicate that the operation will be performed on the column

# %%
# 20
# & - The Dataframe And operator, This operation is done when all conditions are met
# | - The Dataframe Or operator, This operation is done when at least one condition is met
# ~ - The Not operator - filter only the rows in the Dataframe that their values are not equal to the values provided.
# Isin - filter only the rows in the Dataframe that their values are equal to the values provided.
# between - filter only the rows in the Dataframe that their values are between the values provided. ‘inclusive’ parameter will include the last value as well.
